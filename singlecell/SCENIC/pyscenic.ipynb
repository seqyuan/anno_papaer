# %% [markdown]
# # SCENIC python version
# xxxxx
# * asd
# * poi
#
# '''python
# import os
# print('h, w')
# '''
#
# `pip install scanpy`

# %% [markdown]
# ![image1.png](attachment:4c8d118f-2807-4bfe-9fea-5e9d08346e66.png)

# %% [raw]
# .. tags:: singlecell, GRN
